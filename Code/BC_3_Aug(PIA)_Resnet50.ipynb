# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
import os
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import models, transforms
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

# Check if GPU is available
if tf.config.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Using GPU
# Num GPUs Available:  1

# %%
# disease_types = ['Cirrhosis','Fibrosis','No Fibrosis']
# disease_types = ['Cirrhosis','Periportal Fibrosis','Portal Fibrosis','Septal Fibrosis','No Fibrosis']
# disease_types = ['Benign','Malignant','Normal']

disease_types = ['Benign','Malignant','Normal']

# data_dir = '/kaggle/input/aug-pinn/AUG_liver/Liver_Augmented_dataset_PIDA'
data_dir = '/content/BC_Augmentation_PIDA'

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(data_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
class FibrosisDataset(Dataset):
    def __init__(self, dataframe, data_dir, transform=None):
        self.dataframe = dataframe
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = os.path.join(self.data_dir, self.dataframe.iloc[idx, 0])
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        label = self.dataframe.iloc[idx, 1]

        if self.transform:
            image = self.transform(image)
        return image, label

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
dataset = FibrosisDataset(train, data_dir, transform=transform)
total_size = len(dataset)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ResNet50 (without pretrained weights)
model = models.resnet50(pretrained=False)

# Replace classifier head (fc layer in ResNet)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, len(disease_types))

# Freeze all parameters
for param in model.parameters():
    param.requires_grad = False

# Unfreeze only the last 10 parameter tensors
for param in list(model.parameters())[-10:]:
    param.requires_grad = True

model = model.to(device)

# Define loss, optimizer, scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
epochs = 100
train_losses, val_losses, val_accs = [], [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_losses.append(running_loss / len(train_loader))

    # Validation
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    val_losses.append(val_loss / len(val_loader))
    val_accs.append(100 * correct / total)
    scheduler.step()

    print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accs[-1]:.2f}%")
# Out:
# Epoch [1/100], Train Loss: 1.2342, Val Loss: 1.1840, Val Acc: 35.21%
# Epoch [2/100], Train Loss: 1.0304, Val Loss: 1.3174, Val Acc: 33.33%
# Epoch [3/100], Train Loss: 0.9881, Val Loss: 1.3271, Val Acc: 46.01%
# Epoch [4/100], Train Loss: 0.9033, Val Loss: 1.3219, Val Acc: 43.66%
# Epoch [5/100], Train Loss: 0.9085, Val Loss: 1.6454, Val Acc: 37.09%
# Epoch [6/100], Train Loss: 0.8553, Val Loss: 1.4473, Val Acc: 43.66%
# Epoch [7/100], Train Loss: 0.7451, Val Loss: 1.1907, Val Acc: 48.83%
# Epoch [8/100], Train Loss: 0.7107, Val Loss: 1.6228, Val Acc: 42.72%
# Epoch [9/100], Train Loss: 0.6483, Val Loss: 2.8641, Val Acc: 37.56%
# Epoch [10/100], Train Loss: 0.6719, Val Loss: 1.6639, Val Acc: 48.83%
# Epoch [11/100], Train Loss: 0.5571, Val Loss: 2.3018, Val Acc: 43.19%
# Epoch [12/100], Train Loss: 0.5005, Val Loss: 1.1989, Val Acc: 56.81%
# Epoch [13/100], Train Loss: 0.5266, Val Loss: 1.0629, Val Acc: 56.81%
# Epoch [14/100], Train Loss: 0.4834, Val Loss: 1.1455, Val Acc: 54.93%
# Epoch [15/100], Train Loss: 0.4273, Val Loss: 1.6641, Val Acc: 46.48%
# Epoch [16/100], Train Loss: 0.4999, Val Loss: 1.2752, Val Acc: 52.11%
# Epoch [17/100], Train Loss: 0.4306, Val Loss: 1.4240, Val Acc: 55.40%
# Epoch [18/100], Train Loss: 0.3979, Val Loss: 1.7313, Val Acc: 53.99%
# Epoch [19/100], Train Loss: 0.3932, Val Loss: 1.5048, Val Acc: 53.05%
# Epoch [20/100], Train Loss: 0.3713, Val Loss: 1.1459, Val Acc: 57.75%
# Epoch [21/100], Train Loss: 0.3316, Val Loss: 1.1951, Val Acc: 53.99%
# Epoch [22/100], Train Loss: 0.2750, Val Loss: 2.0108, Val Acc: 50.70%
# Epoch [23/100], Train Loss: 0.2635, Val Loss: 1.5538, Val Acc: 53.52%
# Epoch [24/100], Train Loss: 0.2961, Val Loss: 1.2134, Val Acc: 61.03%
# Epoch [25/100], Train Loss: 0.2312, Val Loss: 1.2284, Val Acc: 56.81%
# Epoch [26/100], Train Loss: 0.3157, Val Loss: 1.8002, Val Acc: 50.70%
# Epoch [27/100], Train Loss: 0.2802, Val Loss: 1.1826, Val Acc: 63.38%
# Epoch [28/100], Train Loss: 0.2020, Val Loss: 1.4759, Val Acc: 57.28%
# Epoch [29/100], Train Loss: 0.2642, Val Loss: 1.1743, Val Acc: 59.15%
# Epoch [30/100], Train Loss: 0.2626, Val Loss: 1.4008, Val Acc: 59.15%
# Epoch [31/100], Train Loss: 0.2016, Val Loss: 1.2304, Val Acc: 60.09%
# Epoch [32/100], Train Loss: 0.1821, Val Loss: 1.3540, Val Acc: 59.15%
# Epoch [33/100], Train Loss: 0.1764, Val Loss: 1.5256, Val Acc: 56.81%
# Epoch [34/100], Train Loss: 0.1800, Val Loss: 1.7607, Val Acc: 57.75%
# Epoch [35/100], Train Loss: 0.1589, Val Loss: 1.2542, Val Acc: 61.03%
# Epoch [36/100], Train Loss: 0.1734, Val Loss: 1.3648, Val Acc: 60.56%
# Epoch [37/100], Train Loss: 0.1803, Val Loss: 1.2881, Val Acc: 61.50%
# Epoch [38/100], Train Loss: 0.1424, Val Loss: 1.3161, Val Acc: 58.69%
# Epoch [39/100], Train Loss: 0.1330, Val Loss: 1.2542, Val Acc: 61.97%
# Epoch [40/100], Train Loss: 0.1359, Val Loss: 1.1770, Val Acc: 61.50%
# Epoch [41/100], Train Loss: 0.1312, Val Loss: 1.1307, Val Acc: 61.50%
# Epoch [42/100], Train Loss: 0.1302, Val Loss: 1.2943, Val Acc: 62.44%
# Epoch [43/100], Train Loss: 0.1295, Val Loss: 1.2499, Val Acc: 62.91%
# Epoch [44/100], Train Loss: 0.1388, Val Loss: 1.3757, Val Acc: 59.62%
# Epoch [45/100], Train Loss: 0.1386, Val Loss: 1.1604, Val Acc: 62.44%
# Epoch [46/100], Train Loss: 0.1240, Val Loss: 1.1675, Val Acc: 59.62%
# Epoch [47/100], Train Loss: 0.1322, Val Loss: 1.1972, Val Acc: 61.97%
# Epoch [48/100], Train Loss: 0.0960, Val Loss: 1.1680, Val Acc: 62.91%
# Epoch [49/100], Train Loss: 0.1203, Val Loss: 1.0899, Val Acc: 60.09%
# Epoch [50/100], Train Loss: 0.1373, Val Loss: 1.3449, Val Acc: 64.79%
# Epoch [51/100], Train Loss: 0.0843, Val Loss: 1.2334, Val Acc: 64.32%
# Epoch [52/100], Train Loss: 0.1278, Val Loss: 1.2740, Val Acc: 62.44%
# Epoch [53/100], Train Loss: 0.1290, Val Loss: 1.2873, Val Acc: 59.62%
# Epoch [54/100], Train Loss: 0.1364, Val Loss: 1.1661, Val Acc: 64.32%
# Epoch [55/100], Train Loss: 0.1094, Val Loss: 1.2385, Val Acc: 62.91%
# Epoch [56/100], Train Loss: 0.1155, Val Loss: 1.0927, Val Acc: 62.44%
# Epoch [57/100], Train Loss: 0.1024, Val Loss: 1.2736, Val Acc: 61.50%
# Epoch [58/100], Train Loss: 0.1221, Val Loss: 1.1497, Val Acc: 64.79%
# Epoch [59/100], Train Loss: 0.1058, Val Loss: 1.1345, Val Acc: 59.62%
# Epoch [60/100], Train Loss: 0.1065, Val Loss: 1.1915, Val Acc: 59.15%
# Epoch [61/100], Train Loss: 0.0866, Val Loss: 1.1984, Val Acc: 61.97%
# Epoch [62/100], Train Loss: 0.0936, Val Loss: 1.2178, Val Acc: 61.03%
# Epoch [63/100], Train Loss: 0.1218, Val Loss: 1.3953, Val Acc: 55.87%
# Epoch [64/100], Train Loss: 0.1370, Val Loss: 1.3867, Val Acc: 59.62%
# Epoch [65/100], Train Loss: 0.0792, Val Loss: 1.3584, Val Acc: 61.97%
# Epoch [66/100], Train Loss: 0.1577, Val Loss: 1.3101, Val Acc: 63.38%
# Epoch [67/100], Train Loss: 0.1064, Val Loss: 1.2879, Val Acc: 60.09%
# Epoch [68/100], Train Loss: 0.1840, Val Loss: 1.2378, Val Acc: 62.91%
# Epoch [69/100], Train Loss: 0.1691, Val Loss: 1.0655, Val Acc: 62.91%
# Epoch [70/100], Train Loss: 0.1303, Val Loss: 1.2200, Val Acc: 63.38%
# Epoch [71/100], Train Loss: 0.1457, Val Loss: 1.8763, Val Acc: 56.34%
# Epoch [72/100], Train Loss: 0.1243, Val Loss: 1.2735, Val Acc: 59.15%
# Epoch [73/100], Train Loss: 0.1401, Val Loss: 1.3344, Val Acc: 61.50%
# Epoch [74/100], Train Loss: 0.1235, Val Loss: 2.6335, Val Acc: 47.89%
# Epoch [75/100], Train Loss: 0.1769, Val Loss: 1.9867, Val Acc: 55.40%
# Epoch [76/100], Train Loss: 0.1954, Val Loss: 1.3364, Val Acc: 62.44%
# Epoch [77/100], Train Loss: 0.2009, Val Loss: 1.3363, Val Acc: 58.69%
# Epoch [78/100], Train Loss: 0.1778, Val Loss: 1.3056, Val Acc: 59.62%
# Epoch [79/100], Train Loss: 0.1925, Val Loss: 1.4155, Val Acc: 57.28%
# Epoch [80/100], Train Loss: 0.2019, Val Loss: 2.2809, Val Acc: 48.83%
# Epoch [81/100], Train Loss: 0.2201, Val Loss: 2.6326, Val Acc: 56.81%
# Epoch [82/100], Train Loss: 0.2065, Val Loss: 1.5647, Val Acc: 57.28%
# Epoch [83/100], Train Loss: 0.1625, Val Loss: 1.3586, Val Acc: 56.81%
# Epoch [84/100], Train Loss: 0.1874, Val Loss: 1.3397, Val Acc: 56.34%
# Epoch [85/100], Train Loss: 0.1889, Val Loss: 1.5271, Val Acc: 61.97%
# Epoch [86/100], Train Loss: 0.2515, Val Loss: 1.7257, Val Acc: 53.99%
# Epoch [87/100], Train Loss: 0.1677, Val Loss: 1.9521, Val Acc: 56.81%
# Epoch [88/100], Train Loss: 0.1644, Val Loss: 1.1306, Val Acc: 62.44%
# Epoch [89/100], Train Loss: 0.1856, Val Loss: 2.5398, Val Acc: 48.83%
# Epoch [90/100], Train Loss: 0.1905, Val Loss: 3.0846, Val Acc: 45.54%
# Epoch [91/100], Train Loss: 0.1491, Val Loss: 1.5013, Val Acc: 59.15%
# Epoch [92/100], Train Loss: 0.1900, Val Loss: 2.2272, Val Acc: 51.64%
# Epoch [93/100], Train Loss: 0.2794, Val Loss: 4.5050, Val Acc: 45.07%
# Epoch [94/100], Train Loss: 0.2190, Val Loss: 1.7939, Val Acc: 54.93%
# Epoch [95/100], Train Loss: 0.1653, Val Loss: 3.7530, Val Acc: 47.42%
# Epoch [96/100], Train Loss: 0.2288, Val Loss: 2.9606, Val Acc: 51.17%
# Epoch [97/100], Train Loss: 0.2326, Val Loss: 2.6330, Val Acc: 50.23%
# Epoch [98/100], Train Loss: 0.1584, Val Loss: 2.3934, Val Acc: 50.23%
# Epoch [99/100], Train Loss: 0.1984, Val Loss: 1.7745, Val Acc: 57.28%
# Epoch [100/100], Train Loss: 0.2463, Val Loss: 2.8978, Val Acc: 52.58%

# %%
model.eval()
y_true, y_pred, y_prob = [], [], []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        probs = torch.softmax(outputs, dim=1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_prob.extend(probs.cpu().numpy())

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=disease_types, yticklabels=disease_types)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=disease_types))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.50      0.08      0.14        72
#    Malignant       0.56      0.72      0.63        72
#       Normal       0.50      0.77      0.60        70
#
#     accuracy                           0.52       214
#    macro avg       0.52      0.53      0.46       214
# weighted avg       0.52      0.52      0.46       214

# %%
# ROC AUC
fpr, tpr, roc_auc = {}, {}, {}
y_true_onehot = np.eye(len(disease_types))[y_true]
y_prob = np.array(y_prob)

for i in range(len(disease_types)):
    fpr[i], tpr[i], _ = roc_curve(y_true_onehot[:, i], y_prob[:, i])
    roc_auc[i] = roc_auc_score(y_true_onehot[:, i], y_prob[:, i])

plt.figure(figsize=(8,6))
for i in range(len(disease_types)):
    plt.plot(fpr[i], tpr[i], label=f"{disease_types[i]} (AUC = {roc_auc[i]:.2f})")
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
# Loss & Accuracy Curves
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()

plt.subplot(1,2,2)
plt.plot(val_accs, label='Val Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Validation Accuracy Curve")
plt.legend()
plt.show()

# %%
# torch.save(model, "/kaggle/working/vgg16_baseline_10_layer_trainable_twoclass.pth")
