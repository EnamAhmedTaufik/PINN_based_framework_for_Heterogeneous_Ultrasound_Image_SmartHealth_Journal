# %%
import tensorflow as tf
tf.keras.backend.clear_session()
# Out:
# 2025-08-16 05:48:07.135702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755323287.505466      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755323287.609615      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Lambda, Add, Multiply, Concatenate
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import math

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.layers import Input, Conv2D
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.applications import preprocess_input
from tensorflow.keras import layers, models, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.regularizers import l2

# %%
import tensorflow as tf

# Check if GPU is available
if tf.config.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Using GPU
# Num GPUs Available:  2

# %%
disease_types = ['No Fibrosis','Portal Fibrosis','Periportal Fibrosis','Septal Fibrosis','Cirrhosis']
data_dir = '/kaggle/input/resized-dataset256-lung-disease-raw/Resized_Dataset'
train_dir = os.path.join(data_dir)
# test_dir = os.path.join(data_dir, 'test')

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head(3)
# Out:
#                     File  DiseaseID Disease Type
# 0  No Fibrosis/a9408.jpg          0  No Fibrosis
# 1  No Fibrosis/a1946.jpg          0  No Fibrosis
# 2  No Fibrosis/a8141.jpg          0  No Fibrosis

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# Calculate the counts for each disease type
counts = train.groupby('Disease Type').size()

# Create the vertical bar chart
fig, ax = plt.subplots()
ax.bar(counts.index, counts, color=sns.color_palette('Set2', len(counts)))  # Use Set2 palette for soft colors

# Add labels and title
ax.set_xlabel('Disease Type')
ax.set_ylabel('Count')
ax.set_title('Disease Type Distribution')

# Annotate each bar with the count
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2, p.get_height() + 0.2, f'{int(p.get_height())}',
            ha='center', va='bottom', color='black', fontweight='bold')

# Remove top and right spines for cleaner aesthetics
ax.spines[['top', 'right']].set_visible(False)

# Show the plot
plt.xticks(rotation=20, ha='right')  # Rotate the x-axis labels for readability
plt.tight_layout()  # Adjust layout for tight display
plt.show()

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
train.head(5)
# Out:
#                          File  DiseaseID     Disease Type
# 0       No Fibrosis/a3151.jpg          0      No Fibrosis
# 1         Cirrhosis/u9815.jpg          4        Cirrhosis
# 2         Cirrhosis/T6589.jpg          4        Cirrhosis
# 3  Septal Fibrosis/ct8-66.png          3  Septal Fibrosis
# 4         No Fibrosis/j75.jpg          0      No Fibrosis

# %%
IMAGE_SIZE = 256
SEED = 42
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath))

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = image
X_train = X_train / 255.0
# Out:
# 6343it [01:08, 92.29it/s]

# %%
print('Train Shape: {}'.format(X_train.shape))
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=len(disease_types))
# Out:
# Train Shape: (6343, 256, 256, 3)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.3, random_state=SEED)

# %%
import math
SIZE = 256
N_ch = 3

# %%
class PhysicsInformedLayer(tf.keras.layers.Layer):
    """
    Physics-Informed Neural Network layer for ultrasound physics constraints
    """
    def __init__(self, units=128, **kwargs):
        super(PhysicsInformedLayer, self).__init__(**kwargs)
        self.units = units

    def build(self, input_shape):
        # Physics-based parameters for ultrasound wave propagation
        self.acoustic_impedance_weights = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='acoustic_impedance'
        )

        self.attenuation_weights = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='attenuation'
        )

        self.scattering_weights = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='scattering'
        )

        self.bias = self.add_weight(
            shape=(self.units,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

        super(PhysicsInformedLayer, self).build(input_shape)

    def call(self, inputs, training=None):
        # Apply physics constraints
        # Acoustic impedance modeling (tissue density changes in fibrosis)
        acoustic_component = tf.matmul(inputs, self.acoustic_impedance_weights)

        # Attenuation modeling (increased absorption in fibrotic tissue)
        attenuation_component = tf.matmul(inputs, self.attenuation_weights)
        attenuation_component = tf.nn.sigmoid(attenuation_component) * acoustic_component

        # Scattering modeling (irregular tissue structure in fibrosis)
        scattering_component = tf.matmul(inputs, self.scattering_weights)
        scattering_component = tf.nn.tanh(scattering_component)

        # Physics-informed combination
        physics_output = acoustic_component + attenuation_component * scattering_component
        physics_output = tf.nn.bias_add(physics_output, self.bias)

        return tf.nn.relu(physics_output)

# %%
def ultrasound_physics_loss(y_true, y_pred):
    """
    Custom loss function incorporating ultrasound physics constraints
    """
    # Standard classification loss
    classification_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)

    # Physics constraint: fibrosis progression should be monotonic in severity
    # Assuming classes are ordered by severity (0: normal, 4: severe fibrosis)
    class_indices = tf.argmax(y_pred, axis=-1)
    class_indices_float = tf.cast(class_indices, tf.float32)

    # Smoothness constraint for adjacent predictions
    smoothness_penalty = tf.reduce_mean(tf.square(tf.nn.moments(class_indices_float, axes=[0])[1]))

    # Combine losses
    total_loss = classification_loss + 0.1 * smoothness_penalty

    return total_loss

# %%
def build_resnet_pinn_hybrid():
    """
    Build hybrid ResNet50V2 + PINN model for lung fibrosis classification
    """
    # ResNet50V2 backbone
    resnet = ResNet50V2(weights="imagenet",
                       include_top=False,
                       input_shape=(SIZE, SIZE, N_ch))

    # Fine-tune last 30 layers
    for layer in resnet.layers[:-30]:
        layer.trainable = False
    for layer in resnet.layers[-30:]:
        layer.trainable = True

    # # Input layer
    # input_layer = Input(shape=(SIZE, SIZE, N_ch))

    # # Preprocessing layer to handle single-channel ultrasound if needed
    # x = Conv2D(3, (3, 3), padding='same', activation='relu',
    #            kernel_regularizer=l2(0.001))(input_layer)
    # x = BatchNormalization()(x)

    # # ResNet feature extraction
    # resnet_features = resnet(x)

    # # Additional convolutional layers for ultrasound-specific features
    # x = Conv2D(512, (3, 3), padding='same', activation='relu',
    #            kernel_regularizer=l2(0.001))(resnet_features)
    # x = BatchNormalization()(x)
    # x = Dropout(0.3)(x)

    # x = Conv2D(256, (3, 3), padding='same', activation='relu',
    #            kernel_regularizer=l2(0.001))(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.3)(x)

    # # Global Average Pooling
    # x = GlobalAveragePooling2D()(x)

    # Physics-Informed Neural Network Branch
    physics_branch = PhysicsInformedLayer(units=256, name='physics_layer_1')(x)
    physics_branch = BatchNormalization()(physics_branch)
    physics_branch = Dropout(0.4)(physics_branch)

    physics_branch = PhysicsInformedLayer(units=256, name='physics_layer_2')(physics_branch)
    physics_branch = BatchNormalization()(physics_branch)
    physics_branch = Dropout(0.4)(physics_branch)

    # Standard Dense Branch
    dense_branch = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
    dense_branch = BatchNormalization()(dense_branch)
    dense_branch = Dropout(0.5)(dense_branch)

    dense_branch = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(dense_branch)
    dense_branch = BatchNormalization()(dense_branch)
    dense_branch = Dropout(0.5)(dense_branch)

    # Fusion of physics-informed and standard features
    # Concatenate features for attention mechanism
    concatenated_features = Concatenate(axis=-1)([physics_branch, dense_branch])

    # Attention mechanism for feature fusion
    attention_weights = Dense(1, activation='sigmoid')(concatenated_features)

    # Create complementary attention weights
    complementary_attention = Lambda(lambda x: 1 - x)(attention_weights)

    physics_weighted = Multiply()([physics_branch, attention_weights])
    dense_weighted = Multiply()([dense_branch, complementary_attention])

    fused_features = Add()([physics_weighted, dense_weighted])

    # Final classification layers
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(fused_features)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Output layer for 5-class fibrosis classification
    output = Dense(5, kernel_regularizer=l2(0.01), activation='softmax', name='fibrosis_classification')(x)

    model = Model(input_layer, output)

    return model

# %%
def create_optimized_datasets(X_train, Y_train, X_val, Y_val, batch_size=16):
    """
    Create optimized TensorFlow datasets with data augmentation
    """
    def augment_ultrasound(image, label):
        # Ensure image is float32
        image = tf.cast(image, tf.float32)

        # Ultrasound-specific augmentations
        image = tf.image.random_brightness(image, 0.1)
        image = tf.image.random_contrast(image, 0.8, 1.2)
        image = tf.image.random_flip_left_right(image)

        # Add noise to simulate ultrasound artifacts (ensure same dtype)
        noise = tf.random.normal(tf.shape(image), mean=0.0, stddev=0.02, dtype=tf.float32)
        image = tf.clip_by_value(image + noise, 0.0, 1.0)

        # Ensure output is consistent
        image = tf.cast(image, tf.float32)

        return image, label

    # Training dataset with augmentation
    train_dataset = (
        tf.data.Dataset.from_tensor_slices((X_train, Y_train))
        .shuffle(buffer_size=len(X_train))
        .map(augment_ultrasound, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size, drop_remainder=True)
        .prefetch(tf.data.AUTOTUNE)
        .repeat()
    )

    # Validation dataset without augmentation
    val_dataset = (
        tf.data.Dataset.from_tensor_slices((X_val, Y_val))
        .batch(batch_size, drop_remainder=False)
        .prefetch(tf.data.AUTOTUNE)
    )

    return train_dataset, val_dataset

# %%
def train_hybrid_model(X_train, Y_train, X_val, Y_val):
    """
    Complete training pipeline for ResNet50V2 + PINN hybrid model
    """
    tf.keras.backend.clear_session()

    # Build model
    model = build_resnet_pinn_hybrid()

    # Use a simple fixed learning rate that can be modified by callbacks
    optimizer = Adam(learning_rate=1e-4, clipnorm=1.0)

    model.compile(
        loss=ultrasound_physics_loss,
        optimizer=optimizer,
        metrics=['accuracy']
    )

    model.summary()

    # Callbacks
    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    lr_reducer = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=8,
        verbose=1,
        min_lr=1e-7
    )

    checkpoint = ModelCheckpoint(
        '/kaggle/working/best_resnet_pinn_hybrid.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )

    # Create datasets
    batch_size = 16
    train_dataset, val_dataset = create_optimized_datasets(
        X_train, Y_train, X_val, Y_val, batch_size
    )

    steps_per_epoch = math.ceil(len(X_train) / batch_size)
    validation_steps = math.ceil(len(X_val) / batch_size)

    # Training
    EPOCHS = 100

    print("Starting training of ResNet50V2 + PINN hybrid model...")
    print(f"Training samples: {len(X_train)}")
    print(f"Validation samples: {len(X_val)}")
    print(f"Steps per epoch: {steps_per_epoch}")
    print(f"Validation steps: {validation_steps}")

    history = model.fit(
        train_dataset,
        steps_per_epoch=steps_per_epoch,
        epochs=EPOCHS,
        verbose=1,
        callbacks=[early_stopping, lr_reducer, checkpoint],
        validation_data=val_dataset,
        validation_steps=validation_steps,
        class_weight=None
    )

    return model, history

# %%
def execute_training(X_train, Y_train, X_val, Y_val):
    """
    Execute the complete training pipeline
    """
    print("="*60)
    print("RESNET50V2 + PINN HYBRID MODEL TRAINING")
    print("="*60)

    # Build model
    print("Building ResNet50V2 + PINN Hybrid Model...")
    model = build_resnet_pinn_hybrid()

    print("Model Architecture Summary:")
    model.summary()
    print(f"Total parameters: {model.count_params():,}")
    print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")

    # Start training
    print("\n" + "="*60)
    print("STARTING TRAINING...")
    print("="*60)

    model, history = train_hybrid_model(X_train, Y_train, X_val, Y_val)

    print("\n" + "="*60)
    print("TRAINING COMPLETED!")
    print("="*60)

    return model, history

model, history = execute_training(X_train, Y_train, X_val, Y_val)

print("="*60)
print("READY TO TRAIN!")
print("="*60)
print("To start training, run:")
print("model, history = execute_training(X_train, Y_train, X_val, Y_val)")
print("="*60)
# Out:
# ============================================================
# RESNET50V2 + PINN HYBRID MODEL TRAINING
# ============================================================
# Building ResNet50V2 + PINN Hybrid Model...
# I0000 00:00:1755323384.208999      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1755323384.209755      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model Architecture Summary:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │         84 │ input_layer_1[0]… │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         12 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50v2          │ (None, 8, 8,      │ 23,564,800 │ batch_normalizat… │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 8, 512) │  9,437,696 │ resnet50v2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 256) │  1,179,904 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dropout_1[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ physics_layer_1     │ (None, 256)       │    196,864 │ global_average_p… │
# │ (PhysicsInformedLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    131,584 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ physics_layer_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ physics_layer_2     │ (None, 256)       │    196,864 │ dropout_2[0][0]   │
# │ (PhysicsInformedLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ physics_layer_2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 512)       │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        513 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 1)         │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256)       │          0 │ dropout_3[0][0],  │
# │                     │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 256)       │          0 │ dropout_5[0][0],  │
# │ (Multiply)          │                   │            │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256)       │          0 │ multiply[0][0],   │
# │                     │                   │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     65,792 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fibrosis_classific… │ (None, 5)         │      1,285 │ dropout_6[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 34,915,942 (133.19 MB)
#  Trainable params: 25,790,048 (98.38 MB)
#  Non-trainable params: 9,125,894 (34.81 MB)
# Total parameters: 34,915,942
# Trainable parameters: 25,790,048
#
# ============================================================
# STARTING TRAINING...
# ============================================================
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │         84 │ input_layer_1[0]… │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         12 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50v2          │ (None, 8, 8,      │ 23,564,800 │ batch_normalizat… │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 8, 512) │  9,437,696 │ resnet50v2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 256) │  1,179,904 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dropout_1[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ physics_layer_1     │ (None, 256)       │    196,864 │ global_average_p… │
# │ (PhysicsInformedLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    131,584 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ physics_layer_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ physics_layer_2     │ (None, 256)       │    196,864 │ dropout_2[0][0]   │
# │ (PhysicsInformedLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ physics_layer_2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 512)       │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        513 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 1)         │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256)       │          0 │ dropout_3[0][0],  │
# │                     │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 256)       │          0 │ dropout_5[0][0],  │
# │ (Multiply)          │                   │            │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256)       │          0 │ multiply[0][0],   │
# │                     │                   │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     65,792 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fibrosis_classific… │ (None, 5)         │      1,285 │ dropout_6[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 34,915,942 (133.19 MB)
#  Trainable params: 25,790,048 (98.38 MB)
#  Non-trainable params: 9,125,894 (34.81 MB)
# Starting training of ResNet50V2 + PINN hybrid model...
# Training samples: 4440
# Validation samples: 1903
# Steps per epoch: 278
# Validation steps: 119
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755323449.444968      99 service.cc:148] XLA service 0x7afef4002920 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755323449.447588      99 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1755323449.447613      99 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1755323453.278244      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1755323475.353191      99 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.3188 - loss: 13.1676
# Epoch 1: val_accuracy improved from -inf to 0.51550, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 124s 228ms/step - accuracy: 0.3190 - loss: 13.1665 - val_accuracy: 0.5155 - val_loss: 12.3930 - learning_rate: 1.0000e-04
# Epoch 2/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5035 - loss: 12.2415
# Epoch 2: val_accuracy improved from 0.51550 to 0.55229, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 52s 186ms/step - accuracy: 0.5036 - loss: 12.2411 - val_accuracy: 0.5523 - val_loss: 11.8800 - learning_rate: 1.0000e-04
# Epoch 3/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5451 - loss: 11.6233
# Epoch 3: val_accuracy improved from 0.55229 to 0.65213, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.5451 - loss: 11.6227 - val_accuracy: 0.6521 - val_loss: 10.7761 - learning_rate: 1.0000e-04
# Epoch 4/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5712 - loss: 10.9587
# Epoch 4: val_accuracy did not improve from 0.65213
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 176ms/step - accuracy: 0.5713 - loss: 10.9580 - val_accuracy: 0.6337 - val_loss: 10.5130 - learning_rate: 1.0000e-04
# Epoch 5/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.6220 - loss: 10.1260
# Epoch 5: val_accuracy improved from 0.65213 to 0.67630, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 184ms/step - accuracy: 0.6220 - loss: 10.1254 - val_accuracy: 0.6763 - val_loss: 9.5797 - learning_rate: 1.0000e-04
# Epoch 6/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.6620 - loss: 9.2561
# Epoch 6: val_accuracy did not improve from 0.67630
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.6620 - loss: 9.2554 - val_accuracy: 0.6721 - val_loss: 9.2002 - learning_rate: 1.0000e-04
# Epoch 7/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.6645 - loss: 8.5019
# Epoch 7: val_accuracy improved from 0.67630 to 0.73305, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 184ms/step - accuracy: 0.6645 - loss: 8.5010 - val_accuracy: 0.7331 - val_loss: 7.5501 - learning_rate: 1.0000e-04
# Epoch 8/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7155 - loss: 7.6808
# Epoch 8: val_accuracy did not improve from 0.73305
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - accuracy: 0.7155 - loss: 7.6801 - val_accuracy: 0.7299 - val_loss: 7.0742 - learning_rate: 1.0000e-04
# Epoch 9/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7503 - loss: 6.8551
# Epoch 9: val_accuracy improved from 0.73305 to 0.78245, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 182ms/step - accuracy: 0.7502 - loss: 6.8545 - val_accuracy: 0.7824 - val_loss: 6.1842 - learning_rate: 1.0000e-04
# Epoch 10/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7590 - loss: 6.1100
# Epoch 10: val_accuracy improved from 0.78245 to 0.80084, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 184ms/step - accuracy: 0.7590 - loss: 6.1093 - val_accuracy: 0.8008 - val_loss: 5.3478 - learning_rate: 1.0000e-04
# Epoch 11/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7786 - loss: 5.3993
# Epoch 11: val_accuracy improved from 0.80084 to 0.83920, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.7787 - loss: 5.3986 - val_accuracy: 0.8392 - val_loss: 4.7102 - learning_rate: 1.0000e-04
# Epoch 12/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7958 - loss: 4.7357
# Epoch 12: val_accuracy did not improve from 0.83920
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.7959 - loss: 4.7354 - val_accuracy: 0.8245 - val_loss: 4.3327 - learning_rate: 1.0000e-04
# Epoch 13/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8089 - loss: 4.3371
# Epoch 13: val_accuracy improved from 0.83920 to 0.86968, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 184ms/step - accuracy: 0.8090 - loss: 4.3367 - val_accuracy: 0.8697 - val_loss: 3.8499 - learning_rate: 1.0000e-04
# Epoch 14/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8470 - loss: 3.8412
# Epoch 14: val_accuracy improved from 0.86968 to 0.87283, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.8470 - loss: 3.8408 - val_accuracy: 0.8728 - val_loss: 3.4951 - learning_rate: 1.0000e-04
# Epoch 15/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8621 - loss: 3.4563
# Epoch 15: val_accuracy improved from 0.87283 to 0.89333, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.8622 - loss: 3.4559 - val_accuracy: 0.8933 - val_loss: 3.0299 - learning_rate: 1.0000e-04
# Epoch 16/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8844 - loss: 3.0643
# Epoch 16: val_accuracy did not improve from 0.89333
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.8844 - loss: 3.0639 - val_accuracy: 0.8891 - val_loss: 2.7688 - learning_rate: 1.0000e-04
# Epoch 17/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9081 - loss: 2.6876
# Epoch 17: val_accuracy improved from 0.89333 to 0.90173, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.9081 - loss: 2.6874 - val_accuracy: 0.9017 - val_loss: 2.4663 - learning_rate: 1.0000e-04
# Epoch 18/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9204 - loss: 2.3792
# Epoch 18: val_accuracy improved from 0.90173 to 0.91855, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.9204 - loss: 2.3790 - val_accuracy: 0.9185 - val_loss: 2.2042 - learning_rate: 1.0000e-04
# Epoch 19/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9224 - loss: 2.1723
# Epoch 19: val_accuracy improved from 0.91855 to 0.92486, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.9224 - loss: 2.1720 - val_accuracy: 0.9249 - val_loss: 1.9617 - learning_rate: 1.0000e-04
# Epoch 20/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9475 - loss: 1.8958
# Epoch 20: val_accuracy improved from 0.92486 to 0.93484, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 184ms/step - accuracy: 0.9475 - loss: 1.8957 - val_accuracy: 0.9348 - val_loss: 1.7840 - learning_rate: 1.0000e-04
# Epoch 21/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9551 - loss: 1.7279
# Epoch 21: val_accuracy improved from 0.93484 to 0.94693, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 182ms/step - accuracy: 0.9551 - loss: 1.7278 - val_accuracy: 0.9469 - val_loss: 1.5984 - learning_rate: 1.0000e-04
# Epoch 22/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9565 - loss: 1.5620
# Epoch 22: val_accuracy did not improve from 0.94693
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 174ms/step - accuracy: 0.9565 - loss: 1.5619 - val_accuracy: 0.9138 - val_loss: 1.6648 - learning_rate: 1.0000e-04
# Epoch 23/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9495 - loss: 1.4708
# Epoch 23: val_accuracy did not improve from 0.94693
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 48s 175ms/step - accuracy: 0.9495 - loss: 1.4706 - val_accuracy: 0.9438 - val_loss: 1.3957 - learning_rate: 1.0000e-04
# Epoch 24/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9722 - loss: 1.3304
# Epoch 24: val_accuracy improved from 0.94693 to 0.96111, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.9722 - loss: 1.3302 - val_accuracy: 0.9611 - val_loss: 1.2583 - learning_rate: 1.0000e-04
# Epoch 25/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9657 - loss: 1.2047
# Epoch 25: val_accuracy did not improve from 0.96111
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9657 - loss: 1.2046 - val_accuracy: 0.9580 - val_loss: 1.1609 - learning_rate: 1.0000e-04
# Epoch 26/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9712 - loss: 1.1045
# Epoch 26: val_accuracy did not improve from 0.96111
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9712 - loss: 1.1045 - val_accuracy: 0.9501 - val_loss: 1.1600 - learning_rate: 1.0000e-04
# Epoch 27/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9761 - loss: 1.0625
# Epoch 27: val_accuracy improved from 0.96111 to 0.96269, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.9761 - loss: 1.0624 - val_accuracy: 0.9627 - val_loss: 1.0563 - learning_rate: 1.0000e-04
# Epoch 28/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9704 - loss: 1.0376
# Epoch 28: val_accuracy did not improve from 0.96269
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9705 - loss: 1.0375 - val_accuracy: 0.9543 - val_loss: 1.0328 - learning_rate: 1.0000e-04
# Epoch 29/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9826 - loss: 0.9474
# Epoch 29: val_accuracy improved from 0.96269 to 0.96427, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 185ms/step - accuracy: 0.9826 - loss: 0.9473 - val_accuracy: 0.9643 - val_loss: 0.9774 - learning_rate: 1.0000e-04
# Epoch 30/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9848 - loss: 0.9177
# Epoch 30: val_accuracy did not improve from 0.96427
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9847 - loss: 0.9177 - val_accuracy: 0.9559 - val_loss: 0.9560 - learning_rate: 1.0000e-04
# Epoch 31/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9813 - loss: 0.8729
# Epoch 31: val_accuracy did not improve from 0.96427
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9813 - loss: 0.8729 - val_accuracy: 0.9517 - val_loss: 1.0090 - learning_rate: 1.0000e-04
# Epoch 32/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9814 - loss: 0.8555
# Epoch 32: val_accuracy did not improve from 0.96427
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9814 - loss: 0.8555 - val_accuracy: 0.9280 - val_loss: 1.1153 - learning_rate: 1.0000e-04
# Epoch 33/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9798 - loss: 0.8677
# Epoch 33: val_accuracy did not improve from 0.96427
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9798 - loss: 0.8676 - val_accuracy: 0.9553 - val_loss: 0.8932 - learning_rate: 1.0000e-04
# Epoch 34/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9797 - loss: 0.8376
# Epoch 34: val_accuracy did not improve from 0.96427
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - accuracy: 0.9798 - loss: 0.8376 - val_accuracy: 0.9601 - val_loss: 0.9374 - learning_rate: 1.0000e-04
# Epoch 35/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9847 - loss: 0.8155
# Epoch 35: val_accuracy improved from 0.96427 to 0.97005, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 51s 184ms/step - accuracy: 0.9847 - loss: 0.8154 - val_accuracy: 0.9700 - val_loss: 0.8647 - learning_rate: 1.0000e-04
# Epoch 36/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9877 - loss: 0.8096
# Epoch 36: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9877 - loss: 0.8096 - val_accuracy: 0.9658 - val_loss: 0.8772 - learning_rate: 1.0000e-04
# Epoch 37/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9892 - loss: 0.7904
# Epoch 37: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9892 - loss: 0.7905 - val_accuracy: 0.9643 - val_loss: 0.8969 - learning_rate: 1.0000e-04
# Epoch 38/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9888 - loss: 0.7647
# Epoch 38: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9888 - loss: 0.7647 - val_accuracy: 0.9632 - val_loss: 0.8765 - learning_rate: 1.0000e-04
# Epoch 39/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9899 - loss: 0.7733
# Epoch 39: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9899 - loss: 0.7733 - val_accuracy: 0.9574 - val_loss: 0.9286 - learning_rate: 1.0000e-04
# Epoch 40/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9846 - loss: 0.7820
# Epoch 40: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9846 - loss: 0.7821 - val_accuracy: 0.9559 - val_loss: 0.8700 - learning_rate: 1.0000e-04
# Epoch 41/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9795 - loss: 0.8027
# Epoch 41: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9795 - loss: 0.8026 - val_accuracy: 0.9637 - val_loss: 0.8848 - learning_rate: 1.0000e-04
# Epoch 42/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9836 - loss: 0.8100
# Epoch 42: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9836 - loss: 0.8099 - val_accuracy: 0.9564 - val_loss: 0.9045 - learning_rate: 1.0000e-04
# Epoch 43/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9824 - loss: 0.7795
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 43: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9824 - loss: 0.7794 - val_accuracy: 0.9422 - val_loss: 0.9835 - learning_rate: 1.0000e-04
# Epoch 44/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9956 - loss: 0.7372
# Epoch 44: val_accuracy did not improve from 0.97005
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 178ms/step - accuracy: 0.9956 - loss: 0.7372 - val_accuracy: 0.9700 - val_loss: 0.8426 - learning_rate: 5.0000e-05
# Epoch 45/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9966 - loss: 0.7160
# Epoch 45: val_accuracy improved from 0.97005 to 0.97478, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 52s 186ms/step - accuracy: 0.9966 - loss: 0.7160 - val_accuracy: 0.9748 - val_loss: 0.7972 - learning_rate: 5.0000e-05
# Epoch 46/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9971 - loss: 0.6995
# Epoch 46: val_accuracy did not improve from 0.97478
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 176ms/step - accuracy: 0.9971 - loss: 0.6996 - val_accuracy: 0.9706 - val_loss: 0.8303 - learning_rate: 5.0000e-05
# Epoch 47/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9979 - loss: 0.7055
# Epoch 47: val_accuracy did not improve from 0.97478
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - accuracy: 0.9979 - loss: 0.7055 - val_accuracy: 0.9574 - val_loss: 0.9092 - learning_rate: 5.0000e-05
# Epoch 48/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9970 - loss: 0.6933
# Epoch 48: val_accuracy did not improve from 0.97478
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - accuracy: 0.9970 - loss: 0.6933 - val_accuracy: 0.9669 - val_loss: 0.8499 - learning_rate: 5.0000e-05
# Epoch 49/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9997 - loss: 0.7038
# Epoch 49: val_accuracy did not improve from 0.97478
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9997 - loss: 0.7038 - val_accuracy: 0.9643 - val_loss: 0.9052 - learning_rate: 5.0000e-05
# Epoch 50/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9958 - loss: 0.6729
# Epoch 50: val_accuracy improved from 0.97478 to 0.98108, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 52s 186ms/step - accuracy: 0.9958 - loss: 0.6730 - val_accuracy: 0.9811 - val_loss: 0.7664 - learning_rate: 5.0000e-05
# Epoch 51/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9971 - loss: 0.6899
# Epoch 51: val_accuracy did not improve from 0.98108
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 178ms/step - accuracy: 0.9971 - loss: 0.6900 - val_accuracy: 0.9774 - val_loss: 0.7849 - learning_rate: 5.0000e-05
# Epoch 52/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9940 - loss: 0.7171
# Epoch 52: val_accuracy improved from 0.98108 to 0.98266, saving model to /kaggle/working/best_resnet_pinn_hybrid.keras
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 52s 186ms/step - accuracy: 0.9940 - loss: 0.7170 - val_accuracy: 0.9827 - val_loss: 0.7590 - learning_rate: 5.0000e-05
# Epoch 53/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9966 - loss: 0.7414
# Epoch 53: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9966 - loss: 0.7413 - val_accuracy: 0.9522 - val_loss: 0.9779 - learning_rate: 5.0000e-05
# Epoch 54/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9936 - loss: 0.7149
# Epoch 54: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 53s 190ms/step - accuracy: 0.9936 - loss: 0.7149 - val_accuracy: 0.9727 - val_loss: 0.8361 - learning_rate: 5.0000e-05
# Epoch 55/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9963 - loss: 0.6934
# Epoch 55: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 178ms/step - accuracy: 0.9963 - loss: 0.6933 - val_accuracy: 0.9706 - val_loss: 0.8464 - learning_rate: 5.0000e-05
# Epoch 56/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9982 - loss: 0.7184
# Epoch 56: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9982 - loss: 0.7184 - val_accuracy: 0.9700 - val_loss: 0.8457 - learning_rate: 5.0000e-05
# Epoch 57/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9985 - loss: 0.7211
# Epoch 57: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9985 - loss: 0.7211 - val_accuracy: 0.9674 - val_loss: 0.8455 - learning_rate: 5.0000e-05
# Epoch 58/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9995 - loss: 0.6789
# Epoch 58: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9995 - loss: 0.6789 - val_accuracy: 0.9737 - val_loss: 0.8099 - learning_rate: 5.0000e-05
# Epoch 59/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9952 - loss: 0.6999
# Epoch 59: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 176ms/step - accuracy: 0.9952 - loss: 0.7000 - val_accuracy: 0.9795 - val_loss: 0.7796 - learning_rate: 5.0000e-05
# Epoch 60/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9992 - loss: 0.6592
# Epoch 60: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 60: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - accuracy: 0.9992 - loss: 0.6592 - val_accuracy: 0.9769 - val_loss: 0.7812 - learning_rate: 5.0000e-05
# Epoch 61/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9985 - loss: 0.6931
# Epoch 61: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - accuracy: 0.9985 - loss: 0.6931 - val_accuracy: 0.9821 - val_loss: 0.7709 - learning_rate: 2.5000e-05
# Epoch 62/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9974 - loss: 0.7025
# Epoch 62: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9974 - loss: 0.7025 - val_accuracy: 0.9732 - val_loss: 0.7969 - learning_rate: 2.5000e-05
# Epoch 63/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9998 - loss: 0.6948
# Epoch 63: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9998 - loss: 0.6948 - val_accuracy: 0.9743 - val_loss: 0.8277 - learning_rate: 2.5000e-05
# Epoch 64/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9995 - loss: 0.6705
# Epoch 64: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9995 - loss: 0.6705 - val_accuracy: 0.9758 - val_loss: 0.7946 - learning_rate: 2.5000e-05
# Epoch 65/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9997 - loss: 0.6912
# Epoch 65: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.9997 - loss: 0.6912 - val_accuracy: 0.9795 - val_loss: 0.7837 - learning_rate: 2.5000e-05
# Epoch 66/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.6877
# Epoch 66: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 1.0000 - loss: 0.6877 - val_accuracy: 0.9785 - val_loss: 0.7805 - learning_rate: 2.5000e-05
# Epoch 67/100
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.6638
# Epoch 67: val_accuracy did not improve from 0.98266
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 1.0000 - loss: 0.6639 - val_accuracy: 0.9737 - val_loss: 0.8376 - learning_rate: 2.5000e-05
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 52.
#
# ============================================================
# TRAINING COMPLETED!
# ============================================================
# ============================================================
# READY TO TRAIN!
# ============================================================
# To start training, run:
# model, history = execute_training(X_train, Y_train, X_val, Y_val)
# ============================================================

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (confusion_matrix, classification_report,
                           roc_curve, auc, roc_auc_score, precision_score,
                           recall_score, f1_score)
from sklearn.preprocessing import label_binarize
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# Enable unsafe deserialization for Lambda layers
keras.config.enable_unsafe_deserialization()

# Define custom PhysicsInformedLayer (you need to define this class)
# class PhysicsInformedLayer(keras.layers.Layer):
#     # Your implementation here
#     pass

# def ultrasound_physics_loss(y_true, y_pred):
#     # Your implementation here
#     pass

# Load the trained model with custom objects
custom_objects = {
    'PhysicsInformedLayer': PhysicsInformedLayer,
    'ultrasound_physics_loss': ultrasound_physics_loss
}

print("Loading model with custom objects...")
try:
    model = keras.models.load_model("/kaggle/working/best_resnet_pinn_hybrid.keras",
                                    custom_objects=custom_objects)
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Trying with safe_mode=False...")
    model = keras.models.load_model("/kaggle/working/best_resnet_pinn_hybrid.keras",
                                    custom_objects=custom_objects,
                                    safe_mode=False)
    print("Model loaded successfully with safe_mode=False!")

# Print model summary
print("\nModel Architecture:")
model.summary()

def evaluate_multiclass_model(model, X_test, y_test, class_names=None, history=None):
    """
    Comprehensive multiclass model evaluation function

    Parameters:
    - model: trained Keras model
    - X_test: test features
    - y_test: test labels (categorical/one-hot encoded)
    - class_names: list of class names for labels
    - history: training history object (optional)
    """

    # Make predictions
    print("Making predictions...")
    y_pred_proba = model.predict(X_test, verbose=0)
    y_pred = np.argmax(y_pred_proba, axis=1)
    y_true = np.argmax(y_test, axis=1) if len(y_test.shape) > 1 else y_test

    # Get number of classes
    n_classes = len(np.unique(y_true))
    if class_names is None:
        class_names = [f'Class {i}' for i in range(n_classes)]

    print(f"Number of classes: {n_classes}")
    print(f"Class names: {class_names}")

    # Create figure with subplots
    fig = plt.figure(figsize=(24, 18))

    # 1. Confusion Matrix
    plt.subplot(3, 3, 1)
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)

    # 2. Normalized Confusion Matrix
    plt.subplot(3, 3, 2)
    cm_normalized = confusion_matrix(y_true, y_pred, normalize='true')
    sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Normalized Confusion Matrix (%)', fontsize=14, fontweight='bold')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)

    # 3. Multi-class ROC Curve
    plt.subplot(3, 3, 3)

    # Binarize labels for multiclass ROC
    y_test_bin = label_binarize(y_true, classes=range(n_classes))

    # Compute ROC curve and AUC for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    colors = plt.cm.Set1(np.linspace(0, 1, n_classes))

    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], color=colors[i], lw=2,
                label=f'{class_names[i]} (AUC = {roc_auc[i]:.3f})')

    # Compute micro-average ROC curve
    fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(),
                                              y_pred_proba.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    plt.plot(fpr["micro"], tpr["micro"], color='black', lw=2, linestyle='--',
            label=f'Micro-avg (AUC = {roc_auc["micro"]:.3f})')

    # Compute macro-average ROC curve
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    mean_tpr /= n_classes
    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    plt.plot(fpr["macro"], tpr["macro"], color='red', lw=2, linestyle=':',
            label=f'Macro-avg (AUC = {roc_auc["macro"]:.3f})')

    plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--', alpha=0.5)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves (One-vs-Rest)', fontsize=14, fontweight='bold')
    plt.legend(loc="lower right", fontsize=8)
    plt.grid(True, alpha=0.3)

    # 4. Per-Class Performance Metrics Bar Chart
    plt.subplot(3, 3, 4)

    precision = precision_score(y_true, y_pred, average=None)
    recall = recall_score(y_true, y_pred, average=None)
    f1 = f1_score(y_true, y_pred, average=None)

    x_pos = np.arange(len(class_names))
    width = 0.25

    plt.bar(x_pos - width, precision, width, label='Precision', alpha=0.8, color='skyblue')
    plt.bar(x_pos, recall, width, label='Recall', alpha=0.8, color='lightgreen')
    plt.bar(x_pos + width, f1, width, label='F1-Score', alpha=0.8, color='salmon')

    plt.xlabel('Classes')
    plt.ylabel('Score')
    plt.title('Per-Class Performance Metrics', fontsize=14, fontweight='bold')
    plt.xticks(x_pos, class_names, rotation=45)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.ylim(0, 1.1)

    # 5. Class Distribution
    plt.subplot(3, 3, 5)
    unique, counts = np.unique(y_true, return_counts=True)
    colors_dist = plt.cm.Set3(np.linspace(0, 1, len(unique)))
    plt.pie(counts, labels=[class_names[i] for i in unique], autopct='%1.1f%%',
            colors=colors_dist, startangle=90)
    plt.title('True Class Distribution', fontsize=14, fontweight='bold')

    # 6. Prediction Confidence Distribution
    plt.subplot(3, 3, 6)
    max_probs = np.max(y_pred_proba, axis=1)
    plt.hist(max_probs, bins=30, alpha=0.7, color='purple', edgecolor='black')
    plt.xlabel('Maximum Prediction Probability')
    plt.ylabel('Frequency')
    plt.title('Prediction Confidence Distribution', fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.3)
    plt.axvline(np.mean(max_probs), color='red', linestyle='--',
                label=f'Mean: {np.mean(max_probs):.3f}')
    plt.legend()

    # 7-8. Training History (if provided)
    if history is not None:
        # Loss plot
        plt.subplot(3, 3, 7)
        plt.plot(history.history['loss'], label='Training Loss', linewidth=2, color='blue')
        if 'val_loss' in history.history:
            plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2, color='red')
        plt.title('Model Loss', fontsize=14, fontweight='bold')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend()
        plt.grid(True, alpha=0.3)

        # Accuracy plot
        plt.subplot(3, 3, 8)
        acc_key = 'accuracy' if 'accuracy' in history.history else 'acc'
        val_acc_key = 'val_accuracy' if 'val_accuracy' in history.history else 'val_acc'

        if acc_key in history.history:
            plt.plot(history.history[acc_key], label='Training Accuracy', linewidth=2, color='blue')
        if val_acc_key in history.history:
            plt.plot(history.history[val_acc_key], label='Validation Accuracy', linewidth=2, color='red')

        plt.title('Model Accuracy', fontsize=14, fontweight='bold')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend()
        plt.grid(True, alpha=0.3)

    # 9. Top Misclassifications
    plt.subplot(3, 3, 9)
    misclassified = y_true != y_pred
    if np.sum(misclassified) > 0:
        misclass_true = y_true[misclassified]
        misclass_pred = y_pred[misclassified]

        # Create confusion pairs
        misclass_pairs = [(misclass_true[i], misclass_pred[i]) for i in range(len(misclass_true))]
        unique_pairs, pair_counts = np.unique(misclass_pairs, axis=0, return_counts=True)

        # Sort by frequency
        sorted_indices = np.argsort(pair_counts)[::-1]
        top_pairs = unique_pairs[sorted_indices[:10]]  # Top 10 misclassifications
        top_counts = pair_counts[sorted_indices[:10]]

        labels = [f'{class_names[pair[0]]}→{class_names[pair[1]]}' for pair in top_pairs]

        plt.barh(range(len(top_pairs)), top_counts, color='coral')
        plt.yticks(range(len(top_pairs)), labels)
        plt.xlabel('Count')
        plt.title('Top Misclassifications', fontsize=14, fontweight='bold')
        plt.grid(True, alpha=0.3)
    else:
        plt.text(0.5, 0.5, 'Perfect Classification!\nNo Misclassifications',
                ha='center', va='center', fontsize=12, fontweight='bold')
        plt.xlim(0, 1)
        plt.ylim(0, 1)

    plt.tight_layout()
    plt.show()

    # Print detailed classification report
    print("\n" + "="*70)
    print("DETAILED MULTICLASS CLASSIFICATION REPORT")
    print("="*70)

    # Overall accuracy
    accuracy = np.mean(y_pred == y_true)
    print(f"\nOverall Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")

    # Classification report
    print(f"\nDetailed Classification Report:")
    print("-" * 50)
    print(classification_report(y_true, y_pred, target_names=class_names))

    # ROC AUC Scores
    try:
        roc_auc_ovr = roc_auc_score(y_true, y_pred_proba, multi_class='ovr', average='macro')
        roc_auc_ovo = roc_auc_score(y_true, y_pred_proba, multi_class='ovo', average='macro')
        print(f"ROC AUC Score (One-vs-Rest): {roc_auc_ovr:.4f}")
        print(f"ROC AUC Score (One-vs-One): {roc_auc_ovo:.4f}")
    except Exception as e:
        print(f"Error calculating ROC AUC: {e}")
        roc_auc_ovr = roc_auc["macro"]

    # Average metrics
    avg_precision = np.mean(precision)
    avg_recall = np.mean(recall)
    avg_f1 = np.mean(f1)

    print(f"\nAverage Metrics:")
    print(f"Average Precision: {avg_precision:.4f}")
    print(f"Average Recall: {avg_recall:.4f}")
    print(f"Average F1-Score: {avg_f1:.4f}")

    # Per-class metrics summary
    print(f"\nPer-Class Metrics Summary:")
    print("-" * 50)
    for i, class_name in enumerate(class_names):
        print(f"{class_name}:")
        print(f"  Precision: {precision[i]:.4f}")
        print(f"  Recall: {recall[i]:.4f}")
        print(f"  F1-Score: {f1[i]:.4f}")
        print(f"  ROC AUC: {roc_auc[i]:.4f}")
        print(f"  Support: {np.sum(y_true == i)}")
        print()

    # Model confidence statistics
    print(f"Prediction Confidence Statistics:")
    print(f"Mean confidence: {np.mean(max_probs):.4f}")
    print(f"Std confidence: {np.std(max_probs):.4f}")
    print(f"Min confidence: {np.min(max_probs):.4f}")
    print(f"Max confidence: {np.max(max_probs):.4f}")

    return {
        'accuracy': accuracy,
        'classification_report': classification_report(y_true, y_pred, target_names=class_names, output_dict=True),
        'confusion_matrix': cm,
        'normalized_confusion_matrix': cm_normalized,
        'predictions': y_pred,
        'predicted_probabilities': y_pred_proba,
        'true_labels': y_true,
        'roc_auc_ovr': roc_auc_ovr if 'roc_auc_ovr' in locals() else roc_auc["macro"],
        'per_class_metrics': {
            'precision': precision,
            'recall': recall,
            'f1_score': f1,
            'roc_auc': [roc_auc[i] for i in range(n_classes)]
        },
        'confidence_stats': {
            'mean': np.mean(max_probs),
            'std': np.std(max_probs),
            'min': np.min(max_probs),
            'max': np.max(max_probs)
        }
    }

# Example usage:
print("\n" + "="*50)
print("EVALUATING MODEL PERFORMANCE")
print("="*50)

# Make sure you have these variables defined:
# X_val, Y_val, disease_types, history


results = evaluate_multiclass_model(
    model=model,
    X_test=X_val,
    y_test=Y_val,
    class_names=disease_types,
    history=history
)

# Access individual results
print("\n" + "="*30)
print("FINAL RESULTS SUMMARY")
print("="*30)
print(f"Overall Accuracy: {results['accuracy']:.4f}")
print(f"Overall ROC AUC: {results['roc_auc_ovr']:.4f}")
print(f"Average Precision: {np.mean(results['per_class_metrics']['precision']):.4f}")
print(f"Average Recall: {np.mean(results['per_class_metrics']['recall']):.4f}")
print(f"Average F1-Score: {np.mean(results['per_class_metrics']['f1_score']):.4f}")
# Out:
# Loading model with custom objects...
# Model loaded successfully!
#
# Model Architecture:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │         84 │ input_layer_1[0]… │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         12 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50v2          │ (None, 8, 8,      │ 23,564,800 │ batch_normalizat… │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 8, 512) │  9,437,696 │ resnet50v2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 256) │  1,179,904 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dropout_1[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ physics_layer_1     │ (None, 256)       │    196,864 │ global_average_p… │
# │ (PhysicsInformedLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    131,584 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ physics_layer_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ physics_layer_2     │ (None, 256)       │    196,864 │ dropout_2[0][0]   │
# │ (PhysicsInformedLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ physics_layer_2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 512)       │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        513 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 1)         │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256)       │          0 │ dropout_3[0][0],  │
# │                     │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 256)       │          0 │ dropout_5[0][0],  │
# │ (Multiply)          │                   │            │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256)       │          0 │ multiply[0][0],   │
# │                     │                   │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     65,792 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fibrosis_classific… │ (None, 5)         │      1,285 │ dropout_6[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 86,496,040 (329.96 MB)
#  Trainable params: 25,790,048 (98.38 MB)
#  Non-trainable params: 9,125,894 (34.81 MB)
#  Optimizer params: 51,580,098 (196.76 MB)
# ==================================================
# EVALUATING MODEL PERFORMANCE
# ==================================================
# Making predictions...
# Number of classes: 5
# Class names: ['No Fibrosis', 'Portal Fibrosis', 'Periportal Fibrosis', 'Septal Fibrosis', 'Cirrhosis']
# ======================================================================
# DETAILED MULTICLASS CLASSIFICATION REPORT
# ======================================================================
#
# Overall Accuracy: 0.9827 (98.27%)
#
# Detailed Classification Report:
# --------------------------------------------------
#                      precision    recall  f1-score   support
#
#         No Fibrosis       1.00      1.00      1.00       625
#     Portal Fibrosis       0.95      0.96      0.96       265
# Periportal Fibrosis       0.96      0.95      0.96       250
#     Septal Fibrosis       0.97      0.96      0.97       250
#           Cirrhosis       1.00      1.00      1.00       513
#
#            accuracy                           0.98      1903
#           macro avg       0.98      0.97      0.98      1903
#        weighted avg       0.98      0.98      0.98      1903
#
# ROC AUC Score (One-vs-Rest): 0.9983
# ROC AUC Score (One-vs-One): 0.9976
#
# Average Metrics:
# Average Precision: 0.9755
# Average Recall: 0.9749
# Average F1-Score: 0.9752
#
# Per-Class Metrics Summary:
# --------------------------------------------------
# No Fibrosis:
#   Precision: 0.9984
#   Recall: 1.0000
#   F1-Score: 0.9992
#   ROC AUC: 1.0000
#   Support: 625
#
# Portal Fibrosis:
#   Precision: 0.9515
#   Recall: 0.9623
#   F1-Score: 0.9568
#   ROC AUC: 0.9985
#   Support: 265
#
# Periportal Fibrosis:
#   Precision: 0.9597
#   Recall: 0.9520
#   F1-Score: 0.9558
#   ROC AUC: 0.9946
#   Support: 250
#
# Septal Fibrosis:
#   Precision: 0.9718
#   Recall: 0.9640
#   F1-Score: 0.9679
#   ROC AUC: 0.9985
#   Support: 250
#
# Cirrhosis:
#   Precision: 0.9961
#   Recall: 0.9961
#   F1-Score: 0.9961
#   ROC AUC: 1.0000
#   Support: 513
#
# Prediction Confidence Statistics:
# Mean confidence: 0.9955
# Std confidence: 0.0299
# Min confidence: 0.5525
# Max confidence: 0.9996
#
# ==============================
# FINAL RESULTS SUMMARY
# ==============================
# Overall Accuracy: 0.9827
# Overall ROC AUC: 0.9983
# Average Precision: 0.9755
# Average Recall: 0.9749
# Average F1-Score: 0.9752
