# %%
import tensorflow as tf
tf.keras.backend.clear_session()
# Out:
# 2025-09-02 12:45:01.604689: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756817101.777514      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756817101.827025      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import os
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import models, transforms
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

# Check if GPU is available
if tf.config.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Using GPU
# Num GPUs Available:  2

# %%
# disease_types = ['Cirrhosis','Fibrosis','No Fibrosis']
# disease_types = ['Cirrhosis','Periportal Fibrosis','Portal Fibrosis','Septal Fibrosis','No Fibrosis']
# disease_types = ['Benign','Malignant','Normal']

disease_types = ['Cirrhosis','Periportal Fibrosis','Portal Fibrosis','Septal Fibrosis','No Fibrosis']

data_dir = '/kaggle/input/aug-pinn/AUG_liver/Liver_Augmented_dataset_normal'

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(data_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
class FibrosisDataset(Dataset):
    def __init__(self, dataframe, data_dir, transform=None):
        self.dataframe = dataframe
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = os.path.join(self.data_dir, self.dataframe.iloc[idx, 0])
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        label = self.dataframe.iloc[idx, 1]

        if self.transform:
            image = self.transform(image)
        return image, label

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
dataset = FibrosisDataset(train, data_dir, transform=transform)
total_size = len(dataset)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load VGG16 (without pretrained weights)
model = models.vgg16(pretrained=False)

# Replace classifier head (last layer in classifier)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, len(disease_types))

# Freeze all parameters
for param in model.parameters():
    param.requires_grad = False

# Unfreeze only the last 10 parameter tensors
for param in list(model.parameters())[-10:]:
    param.requires_grad = True

model = model.to(device)

# Define loss, optimizer, scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
epochs = 50
train_losses, val_losses, val_accs = [], [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_losses.append(running_loss / len(train_loader))

    # Validation
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    val_losses.append(val_loss / len(val_loader))
    val_accs.append(100 * correct / total)
    scheduler.step()

    print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accs[-1]:.2f}%")
# Out:
# Epoch [1/50], Train Loss: 1.7828, Val Loss: 1.2507, Val Acc: 41.82%
# Epoch [2/50], Train Loss: 1.1735, Val Loss: 1.0875, Val Acc: 49.10%
# Epoch [3/50], Train Loss: 1.0817, Val Loss: 1.0233, Val Acc: 51.12%
# Epoch [4/50], Train Loss: 1.1825, Val Loss: 1.2754, Val Acc: 42.26%
# Epoch [5/50], Train Loss: 1.1569, Val Loss: 1.1222, Val Acc: 44.51%
# Epoch [6/50], Train Loss: 1.0743, Val Loss: 0.9853, Val Acc: 52.35%
# Epoch [7/50], Train Loss: 0.9567, Val Loss: 1.0110, Val Acc: 53.92%
# Epoch [8/50], Train Loss: 0.9107, Val Loss: 0.9095, Val Acc: 57.17%
# Epoch [9/50], Train Loss: 0.8625, Val Loss: 0.8415, Val Acc: 59.53%
# Epoch [10/50], Train Loss: 0.7988, Val Loss: 0.9013, Val Acc: 57.74%
# Epoch [11/50], Train Loss: 0.7621, Val Loss: 0.7770, Val Acc: 63.23%
# Epoch [12/50], Train Loss: 0.7133, Val Loss: 0.7552, Val Acc: 63.90%
# Epoch [13/50], Train Loss: 0.7136, Val Loss: 0.7286, Val Acc: 65.13%
# Epoch [14/50], Train Loss: 0.6617, Val Loss: 0.7094, Val Acc: 66.48%
# Epoch [15/50], Train Loss: 0.6339, Val Loss: 0.6614, Val Acc: 68.27%
# Epoch [16/50], Train Loss: 0.6196, Val Loss: 0.6739, Val Acc: 67.49%
# Epoch [17/50], Train Loss: 0.6044, Val Loss: 0.6423, Val Acc: 68.05%
# Epoch [18/50], Train Loss: 0.5708, Val Loss: 0.5905, Val Acc: 71.30%
# Epoch [19/50], Train Loss: 0.5490, Val Loss: 0.5955, Val Acc: 71.41%
# Epoch [20/50], Train Loss: 0.5312, Val Loss: 0.5812, Val Acc: 69.51%
# Epoch [21/50], Train Loss: 0.5183, Val Loss: 0.5599, Val Acc: 71.97%
# Epoch [22/50], Train Loss: 0.4978, Val Loss: 0.5534, Val Acc: 72.42%
# Epoch [23/50], Train Loss: 0.4892, Val Loss: 0.5159, Val Acc: 74.10%
# Epoch [24/50], Train Loss: 0.4665, Val Loss: 0.5288, Val Acc: 74.66%
# Epoch [25/50], Train Loss: 0.4598, Val Loss: 0.5383, Val Acc: 71.97%
# Epoch [26/50], Train Loss: 0.4534, Val Loss: 0.5386, Val Acc: 72.76%
# Epoch [27/50], Train Loss: 0.4370, Val Loss: 0.4850, Val Acc: 77.47%
# Epoch [28/50], Train Loss: 0.4167, Val Loss: 0.4879, Val Acc: 74.33%
# Epoch [29/50], Train Loss: 0.4086, Val Loss: 0.4879, Val Acc: 77.13%
# Epoch [30/50], Train Loss: 0.3959, Val Loss: 0.4867, Val Acc: 75.78%
# Epoch [31/50], Train Loss: 0.3831, Val Loss: 0.4806, Val Acc: 76.57%
# Epoch [32/50], Train Loss: 0.3793, Val Loss: 0.4776, Val Acc: 78.14%
# Epoch [33/50], Train Loss: 0.3658, Val Loss: 0.4763, Val Acc: 77.35%
# Epoch [34/50], Train Loss: 0.3544, Val Loss: 0.4638, Val Acc: 78.36%
# Epoch [35/50], Train Loss: 0.3464, Val Loss: 0.4715, Val Acc: 78.25%
# Epoch [36/50], Train Loss: 0.3371, Val Loss: 0.4670, Val Acc: 79.93%
# Epoch [37/50], Train Loss: 0.3298, Val Loss: 0.4701, Val Acc: 79.15%
# Epoch [38/50], Train Loss: 0.3188, Val Loss: 0.4773, Val Acc: 78.81%
# Epoch [39/50], Train Loss: 0.3195, Val Loss: 0.4606, Val Acc: 79.04%
# Epoch [40/50], Train Loss: 0.3116, Val Loss: 0.4829, Val Acc: 77.91%
# Epoch [41/50], Train Loss: 0.3086, Val Loss: 0.4714, Val Acc: 78.36%
# Epoch [42/50], Train Loss: 0.3040, Val Loss: 0.4749, Val Acc: 78.70%
# Epoch [43/50], Train Loss: 0.3031, Val Loss: 0.4799, Val Acc: 79.48%
# Epoch [44/50], Train Loss: 0.2981, Val Loss: 0.4744, Val Acc: 79.60%
# Epoch [45/50], Train Loss: 0.2963, Val Loss: 0.4745, Val Acc: 79.60%
# Epoch [46/50], Train Loss: 0.2927, Val Loss: 0.4747, Val Acc: 79.71%
# Epoch [47/50], Train Loss: 0.2935, Val Loss: 0.4778, Val Acc: 79.37%
# Epoch [48/50], Train Loss: 0.2933, Val Loss: 0.4724, Val Acc: 79.48%
# Epoch [49/50], Train Loss: 0.2914, Val Loss: 0.4739, Val Acc: 79.48%
# Epoch [50/50], Train Loss: 0.2901, Val Loss: 0.4741, Val Acc: 79.48%

# %%
model.eval()
y_true, y_pred, y_prob = [], [], []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        probs = torch.softmax(outputs, dim=1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_prob.extend(probs.cpu().numpy())

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=disease_types, yticklabels=disease_types)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=disease_types))
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#           Cirrhosis       0.99      1.00      0.99       165
# Periportal Fibrosis       0.60      0.77      0.68       172
#     Portal Fibrosis       0.87      0.59      0.70       166
#     Septal Fibrosis       0.70      0.71      0.71       172
#         No Fibrosis       0.99      1.00      1.00       219
#
#            accuracy                           0.82       894
#           macro avg       0.83      0.81      0.81       894
#        weighted avg       0.84      0.82      0.82       894

# %%
# ROC AUC
fpr, tpr, roc_auc = {}, {}, {}
y_true_onehot = np.eye(len(disease_types))[y_true]
y_prob = np.array(y_prob)

for i in range(len(disease_types)):
    fpr[i], tpr[i], _ = roc_curve(y_true_onehot[:, i], y_prob[:, i])
    roc_auc[i] = roc_auc_score(y_true_onehot[:, i], y_prob[:, i])

plt.figure(figsize=(8,6))
for i in range(len(disease_types)):
    plt.plot(fpr[i], tpr[i], label=f"{disease_types[i]} (AUC = {roc_auc[i]:.2f})")
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
# Loss & Accuracy Curves
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()

plt.subplot(1,2,2)
plt.plot(val_accs, label='Val Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Validation Accuracy Curve")
plt.legend()
plt.show()

# %%
torch.save(model, "/kaggle/working/vgg16_baseline_10_layer_trainable_twoclass.pth")
