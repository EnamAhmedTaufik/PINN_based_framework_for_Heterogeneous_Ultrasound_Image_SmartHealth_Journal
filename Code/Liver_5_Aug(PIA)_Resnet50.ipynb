# %%
import tensorflow as tf
tf.keras.backend.clear_session()
# Out:
# 2025-09-02 08:04:14.124813: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756800254.273606      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756800254.320153      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import os
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import models, transforms
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

# Check if GPU is available
if tf.config.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Using GPU
# Num GPUs Available:  2

# %%
# disease_types = ['Cirrhosis','Fibrosis','No Fibrosis']
# disease_types = ['Cirrhosis','Periportal Fibrosis','Portal Fibrosis','Septal Fibrosis','No Fibrosis']
# disease_types = ['Benign','Malignant','Normal']

disease_types = ['Cirrhosis','Periportal Fibrosis','Portal Fibrosis','Septal Fibrosis','No Fibrosis']

data_dir = '/kaggle/input/aug-pinn/AUG_liver/Liver_Augmented_dataset_PIDA'

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(data_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
class FibrosisDataset(Dataset):
    def __init__(self, dataframe, data_dir, transform=None):
        self.dataframe = dataframe
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = os.path.join(self.data_dir, self.dataframe.iloc[idx, 0])
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        label = self.dataframe.iloc[idx, 1]

        if self.transform:
            image = self.transform(image)
        return image, label

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
dataset = FibrosisDataset(train, data_dir, transform=transform)
total_size = len(dataset)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ResNet50 (without pretrained weights)
model = models.resnet50(pretrained=False)

# Replace classifier head (fc layer in ResNet)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, len(disease_types))

# Freeze all parameters
for param in model.parameters():
    param.requires_grad = False

# Unfreeze only the last 10 parameter tensors
for param in list(model.parameters())[-10:]:
    param.requires_grad = True

model = model.to(device)

# Define loss, optimizer, scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
epochs = 50
train_losses, val_losses, val_accs = [], [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_losses.append(running_loss / len(train_loader))

    # Validation
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    val_losses.append(val_loss / len(val_loader))
    val_accs.append(100 * correct / total)
    scheduler.step()

    print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accs[-1]:.2f}%")
# Out:
# Epoch [1/50], Train Loss: 1.1794, Val Loss: 1.5220, Val Acc: 45.40%
# Epoch [2/50], Train Loss: 0.8167, Val Loss: 0.8069, Val Acc: 67.15%
# Epoch [3/50], Train Loss: 0.6763, Val Loss: 1.0053, Val Acc: 61.43%
# Epoch [4/50], Train Loss: 0.5663, Val Loss: 0.8883, Val Acc: 69.39%
# Epoch [5/50], Train Loss: 0.4570, Val Loss: 0.6887, Val Acc: 74.78%
# Epoch [6/50], Train Loss: 0.3862, Val Loss: 0.6476, Val Acc: 74.89%
# Epoch [7/50], Train Loss: 0.3239, Val Loss: 0.7312, Val Acc: 76.01%
# Epoch [8/50], Train Loss: 0.2674, Val Loss: 0.8397, Val Acc: 71.75%
# Epoch [9/50], Train Loss: 0.2445, Val Loss: 0.5799, Val Acc: 80.16%
# Epoch [10/50], Train Loss: 0.2128, Val Loss: 1.4684, Val Acc: 69.51%
# Epoch [11/50], Train Loss: 0.2003, Val Loss: 0.9863, Val Acc: 75.22%
# Epoch [12/50], Train Loss: 0.1594, Val Loss: 0.5704, Val Acc: 82.29%
# Epoch [13/50], Train Loss: 0.1585, Val Loss: 1.4190, Val Acc: 66.48%
# Epoch [14/50], Train Loss: 0.1282, Val Loss: 0.5269, Val Acc: 84.08%
# Epoch [15/50], Train Loss: 0.1030, Val Loss: 0.9140, Val Acc: 78.36%
# Epoch [16/50], Train Loss: 0.1002, Val Loss: 0.7865, Val Acc: 77.24%
# Epoch [17/50], Train Loss: 0.0784, Val Loss: 0.6060, Val Acc: 83.86%
# Epoch [18/50], Train Loss: 0.0755, Val Loss: 0.7155, Val Acc: 81.84%
# Epoch [19/50], Train Loss: 0.0614, Val Loss: 0.6889, Val Acc: 84.08%
# Epoch [20/50], Train Loss: 0.0543, Val Loss: 0.7820, Val Acc: 82.17%
# Epoch [21/50], Train Loss: 0.0693, Val Loss: 0.4955, Val Acc: 86.77%
# Epoch [22/50], Train Loss: 0.0518, Val Loss: 0.6953, Val Acc: 83.30%
# Epoch [23/50], Train Loss: 0.0575, Val Loss: 0.4977, Val Acc: 86.88%
# Epoch [24/50], Train Loss: 0.0519, Val Loss: 0.6545, Val Acc: 82.62%
# Epoch [25/50], Train Loss: 0.0296, Val Loss: 0.7652, Val Acc: 82.96%
# Epoch [26/50], Train Loss: 0.0336, Val Loss: 0.5284, Val Acc: 85.87%
# Epoch [27/50], Train Loss: 0.0344, Val Loss: 0.7125, Val Acc: 82.74%
# Epoch [28/50], Train Loss: 0.0359, Val Loss: 0.6389, Val Acc: 84.75%
# Epoch [29/50], Train Loss: 0.0240, Val Loss: 0.5893, Val Acc: 84.64%
# Epoch [30/50], Train Loss: 0.0300, Val Loss: 0.5627, Val Acc: 85.87%
# Epoch [31/50], Train Loss: 0.0273, Val Loss: 0.8171, Val Acc: 83.18%
# Epoch [32/50], Train Loss: 0.0175, Val Loss: 0.5753, Val Acc: 86.21%
# Epoch [33/50], Train Loss: 0.0249, Val Loss: 0.5154, Val Acc: 87.56%
# Epoch [34/50], Train Loss: 0.0179, Val Loss: 0.5391, Val Acc: 87.22%
# Epoch [35/50], Train Loss: 0.0149, Val Loss: 0.7169, Val Acc: 83.97%
# Epoch [36/50], Train Loss: 0.0172, Val Loss: 0.4999, Val Acc: 87.11%
# Epoch [37/50], Train Loss: 0.0081, Val Loss: 0.7670, Val Acc: 85.09%
# Epoch [38/50], Train Loss: 0.0123, Val Loss: 0.6412, Val Acc: 86.43%
# Epoch [39/50], Train Loss: 0.0150, Val Loss: 0.5357, Val Acc: 86.10%
# Epoch [40/50], Train Loss: 0.0106, Val Loss: 0.5778, Val Acc: 87.00%
# Epoch [41/50], Train Loss: 0.0074, Val Loss: 0.5351, Val Acc: 87.67%
# Epoch [42/50], Train Loss: 0.0062, Val Loss: 0.5206, Val Acc: 87.44%
# Epoch [43/50], Train Loss: 0.0070, Val Loss: 0.5451, Val Acc: 87.11%
# Epoch [44/50], Train Loss: 0.0049, Val Loss: 0.5155, Val Acc: 87.00%
# Epoch [45/50], Train Loss: 0.0075, Val Loss: 0.5291, Val Acc: 87.89%
# Epoch [46/50], Train Loss: 0.0077, Val Loss: 0.5402, Val Acc: 87.89%
# Epoch [47/50], Train Loss: 0.0038, Val Loss: 0.5344, Val Acc: 87.89%
# Epoch [48/50], Train Loss: 0.0076, Val Loss: 0.5492, Val Acc: 87.44%
# Epoch [49/50], Train Loss: 0.0112, Val Loss: 0.5320, Val Acc: 88.12%
# Epoch [50/50], Train Loss: 0.0052, Val Loss: 0.5454, Val Acc: 87.33%

# %%
model.eval()
y_true, y_pred, y_prob = [], [], []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        probs = torch.softmax(outputs, dim=1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_prob.extend(probs.cpu().numpy())

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=disease_types, yticklabels=disease_types)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=disease_types))
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#           Cirrhosis       0.97      0.98      0.97       165
# Periportal Fibrosis       0.78      0.84      0.81       172
#     Portal Fibrosis       0.86      0.82      0.84       166
#     Septal Fibrosis       0.86      0.81      0.83       172
#         No Fibrosis       0.98      1.00      0.99       219
#
#            accuracy                           0.89       894
#           macro avg       0.89      0.89      0.89       894
#        weighted avg       0.89      0.89      0.89       894

# %%
# ROC AUC
fpr, tpr, roc_auc = {}, {}, {}
y_true_onehot = np.eye(len(disease_types))[y_true]
y_prob = np.array(y_prob)

for i in range(len(disease_types)):
    fpr[i], tpr[i], _ = roc_curve(y_true_onehot[:, i], y_prob[:, i])
    roc_auc[i] = roc_auc_score(y_true_onehot[:, i], y_prob[:, i])

plt.figure(figsize=(8,6))
for i in range(len(disease_types)):
    plt.plot(fpr[i], tpr[i], label=f"{disease_types[i]} (AUC = {roc_auc[i]:.2f})")
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
# Loss & Accuracy Curves
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()

plt.subplot(1,2,2)
plt.plot(val_accs, label='Val Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Validation Accuracy Curve")
plt.legend()
plt.show()

# %%
torch.save(model, "/kaggle/working/vgg16_baseline_10_layer_trainable_twoclass.pth")
