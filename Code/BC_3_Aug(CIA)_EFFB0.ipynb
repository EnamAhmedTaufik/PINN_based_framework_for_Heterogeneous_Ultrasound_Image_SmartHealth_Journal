# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
import os
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import models, transforms
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

# Check if GPU is available
if tf.config.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Using GPU
# Num GPUs Available:  1

# %%
# disease_types = ['Cirrhosis','Fibrosis','No Fibrosis']
# disease_types = ['Cirrhosis','Periportal Fibrosis','Portal Fibrosis','Septal Fibrosis','No Fibrosis']
# disease_types = ['Benign','Malignant','Normal']

disease_types = ['Benign','Malignant','Normal']

# data_dir = '/kaggle/input/aug-pinn/AUG_liver/Liver_Augmented_dataset_normal'
data_dir = '/content/BC_Augmented_dataset_normal'

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(data_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
class FibrosisDataset(Dataset):
    def __init__(self, dataframe, data_dir, transform=None):
        self.dataframe = dataframe
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = os.path.join(self.data_dir, self.dataframe.iloc[idx, 0])
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        label = self.dataframe.iloc[idx, 1]

        if self.transform:
            image = self.transform(image)
        return image, label

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
dataset = FibrosisDataset(train, data_dir, transform=transform)
total_size = len(dataset)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load EfficientNet-B0 (without pretrained weights)
model = models.efficientnet_b0(pretrained=False)

# Replace classifier head (classifier in EfficientNet)
num_ftrs = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_ftrs, len(disease_types))

# Freeze all parameters
for param in model.parameters():
    param.requires_grad = False

# Unfreeze only the last 10 parameter tensors
for param in list(model.parameters())[-10:]:
    param.requires_grad = True

model = model.to(device)

# Define loss, optimizer, scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
epochs = 100
train_losses, val_losses, val_accs = [], [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_losses.append(running_loss / len(train_loader))

    # Validation
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    val_losses.append(val_loss / len(val_loader))
    val_accs.append(100 * correct / total)
    scheduler.step()

    print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accs[-1]:.2f}%")
# Out:
# Epoch [1/100], Train Loss: 1.2032, Val Loss: 1.1058, Val Acc: 35.21%
# Epoch [2/100], Train Loss: 1.1452, Val Loss: 1.1014, Val Acc: 35.21%
# Epoch [3/100], Train Loss: 1.0946, Val Loss: 1.1105, Val Acc: 34.27%
# Epoch [4/100], Train Loss: 1.0813, Val Loss: 1.0758, Val Acc: 43.19%
# Epoch [5/100], Train Loss: 1.0583, Val Loss: 1.0805, Val Acc: 42.72%
# Epoch [6/100], Train Loss: 1.0524, Val Loss: 1.0523, Val Acc: 43.66%
# Epoch [7/100], Train Loss: 1.0509, Val Loss: 1.0456, Val Acc: 46.01%
# Epoch [8/100], Train Loss: 1.0543, Val Loss: 1.0339, Val Acc: 44.60%
# Epoch [9/100], Train Loss: 1.0349, Val Loss: 1.0210, Val Acc: 45.54%
# Epoch [10/100], Train Loss: 1.0265, Val Loss: 1.0279, Val Acc: 47.89%
# Epoch [11/100], Train Loss: 1.0206, Val Loss: 1.0673, Val Acc: 43.19%
# Epoch [12/100], Train Loss: 1.0265, Val Loss: 1.0304, Val Acc: 46.48%
# Epoch [13/100], Train Loss: 0.9911, Val Loss: 1.0439, Val Acc: 44.60%
# Epoch [14/100], Train Loss: 1.0052, Val Loss: 1.0212, Val Acc: 42.25%
# Epoch [15/100], Train Loss: 0.9999, Val Loss: 1.0353, Val Acc: 45.07%
# Epoch [16/100], Train Loss: 0.9984, Val Loss: 1.0431, Val Acc: 44.13%
# Epoch [17/100], Train Loss: 0.9973, Val Loss: 1.0774, Val Acc: 46.48%
# Epoch [18/100], Train Loss: 0.9997, Val Loss: 1.0455, Val Acc: 42.72%
# Epoch [19/100], Train Loss: 0.9623, Val Loss: 1.0165, Val Acc: 45.07%
# Epoch [20/100], Train Loss: 0.9678, Val Loss: 1.0122, Val Acc: 41.78%
# Epoch [21/100], Train Loss: 0.9724, Val Loss: 1.0280, Val Acc: 46.48%
# Epoch [22/100], Train Loss: 0.9475, Val Loss: 1.0231, Val Acc: 45.54%
# Epoch [23/100], Train Loss: 0.9691, Val Loss: 1.0475, Val Acc: 48.36%
# Epoch [24/100], Train Loss: 0.9438, Val Loss: 1.0341, Val Acc: 46.48%
# Epoch [25/100], Train Loss: 0.9455, Val Loss: 1.0170, Val Acc: 46.48%
# Epoch [26/100], Train Loss: 0.9509, Val Loss: 1.0091, Val Acc: 45.54%
# Epoch [27/100], Train Loss: 0.9358, Val Loss: 1.0214, Val Acc: 46.01%
# Epoch [28/100], Train Loss: 0.9463, Val Loss: 1.0215, Val Acc: 42.72%
# Epoch [29/100], Train Loss: 0.9413, Val Loss: 1.0083, Val Acc: 48.83%
# Epoch [30/100], Train Loss: 0.9401, Val Loss: 1.0201, Val Acc: 45.54%
# Epoch [31/100], Train Loss: 0.9506, Val Loss: 1.0158, Val Acc: 46.01%
# Epoch [32/100], Train Loss: 0.9264, Val Loss: 1.0159, Val Acc: 46.01%
# Epoch [33/100], Train Loss: 0.9339, Val Loss: 1.0079, Val Acc: 48.83%
# Epoch [34/100], Train Loss: 0.9156, Val Loss: 1.0353, Val Acc: 46.48%
# Epoch [35/100], Train Loss: 0.9000, Val Loss: 1.0127, Val Acc: 48.36%
# Epoch [36/100], Train Loss: 0.9052, Val Loss: 1.0392, Val Acc: 46.01%
# Epoch [37/100], Train Loss: 0.9043, Val Loss: 1.0201, Val Acc: 45.07%
# Epoch [38/100], Train Loss: 0.8990, Val Loss: 1.0261, Val Acc: 47.42%
# Epoch [39/100], Train Loss: 0.9197, Val Loss: 1.0176, Val Acc: 46.95%
# Epoch [40/100], Train Loss: 0.8901, Val Loss: 1.0285, Val Acc: 45.54%
# Epoch [41/100], Train Loss: 0.8965, Val Loss: 1.0208, Val Acc: 49.77%
# Epoch [42/100], Train Loss: 0.8890, Val Loss: 1.0193, Val Acc: 46.48%
# Epoch [43/100], Train Loss: 0.8915, Val Loss: 1.0243, Val Acc: 45.54%
# Epoch [44/100], Train Loss: 0.8794, Val Loss: 1.0145, Val Acc: 46.48%
# Epoch [45/100], Train Loss: 0.8684, Val Loss: 1.0388, Val Acc: 47.89%
# Epoch [46/100], Train Loss: 0.8762, Val Loss: 1.0283, Val Acc: 46.48%
# Epoch [47/100], Train Loss: 0.8974, Val Loss: 1.0206, Val Acc: 45.54%
# Epoch [48/100], Train Loss: 0.8787, Val Loss: 1.0175, Val Acc: 46.95%
# Epoch [49/100], Train Loss: 0.8892, Val Loss: 1.0181, Val Acc: 45.54%
# Epoch [50/100], Train Loss: 0.8722, Val Loss: 1.0235, Val Acc: 46.01%
# Epoch [51/100], Train Loss: 0.9011, Val Loss: 1.0310, Val Acc: 47.42%
# Epoch [52/100], Train Loss: 0.8738, Val Loss: 1.0212, Val Acc: 46.01%
# Epoch [53/100], Train Loss: 0.8860, Val Loss: 1.0233, Val Acc: 44.13%
# Epoch [54/100], Train Loss: 0.8851, Val Loss: 1.0473, Val Acc: 45.54%
# Epoch [55/100], Train Loss: 0.8901, Val Loss: 1.0497, Val Acc: 46.95%
# Epoch [56/100], Train Loss: 0.8981, Val Loss: 1.0222, Val Acc: 46.95%
# Epoch [57/100], Train Loss: 0.8781, Val Loss: 1.0267, Val Acc: 47.42%
# Epoch [58/100], Train Loss: 0.8955, Val Loss: 1.0519, Val Acc: 48.83%
# Epoch [59/100], Train Loss: 0.8983, Val Loss: 1.0169, Val Acc: 46.48%
# Epoch [60/100], Train Loss: 0.8784, Val Loss: 1.0136, Val Acc: 48.83%
# Epoch [61/100], Train Loss: 0.8842, Val Loss: 1.0209, Val Acc: 46.01%
# Epoch [62/100], Train Loss: 0.9008, Val Loss: 1.0448, Val Acc: 47.42%
# Epoch [63/100], Train Loss: 0.8920, Val Loss: 1.0162, Val Acc: 47.42%
# Epoch [64/100], Train Loss: 0.9119, Val Loss: 1.0083, Val Acc: 47.89%
# Epoch [65/100], Train Loss: 0.8819, Val Loss: 1.0223, Val Acc: 46.01%
# Epoch [66/100], Train Loss: 0.8917, Val Loss: 1.0333, Val Acc: 46.48%
# Epoch [67/100], Train Loss: 0.9024, Val Loss: 1.0346, Val Acc: 45.54%
# Epoch [68/100], Train Loss: 0.8762, Val Loss: 1.0453, Val Acc: 45.54%
# Epoch [69/100], Train Loss: 0.9236, Val Loss: 1.0054, Val Acc: 47.89%
# Epoch [70/100], Train Loss: 0.8882, Val Loss: 1.0091, Val Acc: 46.95%
# Epoch [71/100], Train Loss: 0.8976, Val Loss: 1.0087, Val Acc: 49.30%
# Epoch [72/100], Train Loss: 0.8851, Val Loss: 1.0299, Val Acc: 46.95%
# Epoch [73/100], Train Loss: 0.8827, Val Loss: 1.0205, Val Acc: 45.07%
# Epoch [74/100], Train Loss: 0.8895, Val Loss: 1.0410, Val Acc: 45.54%
# Epoch [75/100], Train Loss: 0.9056, Val Loss: 1.0776, Val Acc: 48.36%
# Epoch [76/100], Train Loss: 0.8871, Val Loss: 1.0328, Val Acc: 45.07%
# Epoch [77/100], Train Loss: 0.8654, Val Loss: 1.0306, Val Acc: 46.95%
# Epoch [78/100], Train Loss: 0.8733, Val Loss: 1.0404, Val Acc: 42.72%
# Epoch [79/100], Train Loss: 0.8972, Val Loss: 1.0359, Val Acc: 47.89%
# Epoch [80/100], Train Loss: 0.9474, Val Loss: 1.0154, Val Acc: 49.30%
# Epoch [81/100], Train Loss: 0.8865, Val Loss: 1.0099, Val Acc: 46.48%
# Epoch [82/100], Train Loss: 0.9164, Val Loss: 1.0424, Val Acc: 46.95%
# Epoch [83/100], Train Loss: 0.8962, Val Loss: 1.0206, Val Acc: 48.36%
# Epoch [84/100], Train Loss: 0.8890, Val Loss: 1.0201, Val Acc: 46.48%
# Epoch [85/100], Train Loss: 0.8874, Val Loss: 1.0109, Val Acc: 43.19%
# Epoch [86/100], Train Loss: 0.8888, Val Loss: 1.0096, Val Acc: 46.95%
# Epoch [87/100], Train Loss: 0.8697, Val Loss: 1.0219, Val Acc: 48.83%
# Epoch [88/100], Train Loss: 0.8766, Val Loss: 1.0259, Val Acc: 51.17%
# Epoch [89/100], Train Loss: 0.8870, Val Loss: 1.0104, Val Acc: 42.25%
# Epoch [90/100], Train Loss: 0.9058, Val Loss: 0.9997, Val Acc: 41.78%
# Epoch [91/100], Train Loss: 0.8954, Val Loss: 1.0466, Val Acc: 46.01%
# Epoch [92/100], Train Loss: 0.8818, Val Loss: 1.0077, Val Acc: 50.70%
# Epoch [93/100], Train Loss: 0.8849, Val Loss: 1.0457, Val Acc: 45.54%
# Epoch [94/100], Train Loss: 0.8614, Val Loss: 1.0580, Val Acc: 44.13%
# Epoch [95/100], Train Loss: 0.8536, Val Loss: 1.0399, Val Acc: 43.66%
# Epoch [96/100], Train Loss: 0.8823, Val Loss: 1.0483, Val Acc: 48.36%
# Epoch [97/100], Train Loss: 0.8716, Val Loss: 1.0681, Val Acc: 45.54%
# Epoch [98/100], Train Loss: 0.8961, Val Loss: 0.9944, Val Acc: 47.89%
# Epoch [99/100], Train Loss: 0.8659, Val Loss: 1.0989, Val Acc: 41.78%
# Epoch [100/100], Train Loss: 0.8718, Val Loss: 1.0202, Val Acc: 49.30%

# %%
model.eval()
y_true, y_pred, y_prob = [], [], []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        probs = torch.softmax(outputs, dim=1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_prob.extend(probs.cpu().numpy())

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=disease_types, yticklabels=disease_types)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=disease_types))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.51      0.32      0.39        72
#    Malignant       0.54      0.58      0.56        72
#       Normal       0.47      0.61      0.53        70
#
#     accuracy                           0.50       214
#    macro avg       0.51      0.51      0.50       214
# weighted avg       0.51      0.50      0.50       214

# %%
# ROC AUC
fpr, tpr, roc_auc = {}, {}, {}
y_true_onehot = np.eye(len(disease_types))[y_true]
y_prob = np.array(y_prob)

for i in range(len(disease_types)):
    fpr[i], tpr[i], _ = roc_curve(y_true_onehot[:, i], y_prob[:, i])
    roc_auc[i] = roc_auc_score(y_true_onehot[:, i], y_prob[:, i])

plt.figure(figsize=(8,6))
for i in range(len(disease_types)):
    plt.plot(fpr[i], tpr[i], label=f"{disease_types[i]} (AUC = {roc_auc[i]:.2f})")
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
# Loss & Accuracy Curves
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()

plt.subplot(1,2,2)
plt.plot(val_accs, label='Val Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Validation Accuracy Curve")
plt.legend()
plt.show()

# %%
# torch.save(model, "/kaggle/working/vgg16_baseline_10_layer_trainable_twoclass.pth")
